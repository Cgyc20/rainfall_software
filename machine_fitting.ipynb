# %%
import pandas as pd
import numpy as np
from netCDF4 import Dataset, num2date
import nctoolkit as nc
import matplotlib.pyplot as plt
# Out:
# nctoolkit is using Climate Data Operators version 2.3.0

# %%
from plot_functions import data_manipulation
#data_path  = '/Users/charliecameron/CodingHub/Uni/Data_driven_processes/Data_modelling/data_sets/data_aus.nc'
data_path = '/Users/charliecameron/CodingHub/Uni/Data_driven_processes/Data_modelling/rainfall_software/DATA/data_alice_springs.nc'
#Now we can create an instance using the data_manipulation class
data_class = data_manipulation(data_path)

# %%
print(data_class.metadata['lon'])

print(data_class.metadata['lat'])

data = data_class.data
# Out:
# [133.  133.1 133.2 133.3 133.4 133.5 133.6 133.7 133.8 133.9 134. ]
# [-23.  -23.1 -23.2 -23.3 -23.4 -23.5 -23.6 -23.7 -23.8 -23.9 -24. ]

# %%
rainfall_data = data_class.data.variables['tp'][:]


print(rainfall_data.shape)
# Out:
# (876, 11, 11)

# %%
data_class.data.variables['latitude'][:]
# Out:
# masked_array(data=[-23. , -23.1, -23.2, -23.3, -23.4, -23.5, -23.6, -23.7,
#                    -23.8, -23.9, -24. ],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
data_class.metadata['dates']
# Out:
# masked_array(data=[cftime.DatetimeGregorian(1950, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1950, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1951, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1952, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1953, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1954, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1955, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1956, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1957, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1958, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1959, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1960, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1961, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1962, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1963, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1964, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1965, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1966, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1967, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1968, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1969, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1970, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1971, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1972, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(1972, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(
 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2020, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2021, 12, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 1, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 2, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 3, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 4, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 5, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 6, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 7, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 8, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 9, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 10, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 11, 1, 0, 0, 0, 0, has_year_zero=False),
#                    cftime.DatetimeGregorian(2022, 12, 1, 0, 0, 0, 0, has_year_zero=False)],
#              mask=False,
#        fill_value='?',
#             dtype=object)

# %%
big_df_list = []
from datetime import datetime

big_df = pd.DataFrame(columns=['tp', 'date', 'lat', 'lon'])  # Ensure big_df is initialized

for i in range(11):
    for j in range(11):             
        temp_df = pd.DataFrame({
            'tp': rainfall_data[:,i,j],
            'date': data_class.metadata['dates'],
            'lat': data_class.data.variables['latitude'][i],
            'lon': data_class.data.variables['longitude'][j]
        })
        big_df_list.append(temp_df)  # Append temp_df to big_df

big_df = pd.concat(big_df_list,ignore_index=True)

big_df.head()
big_df['month'] = pd.to_datetime(big_df['date'].astype('str')).dt.month
big_df['year'] = pd.to_datetime(big_df['date'].astype('str')).dt.year

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

x_cols = ['year','month','lon','lat']
y_cols = ['tp']

X_data = big_df[x_cols]
Y_data = big_df[y_cols]


x_train, x_test, y_train, y_test = train_test_split(X_data,Y_data,test_size=0.2,random_state=0,shuffle = True)

# %%
model_1 = RandomForestRegressor(n_estimators=100,random_state=0)
model_1.fit(x_train,y_train)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(random_state=0)

# %%
from sklearn.metrics import mean_squared_error
y_pred = model_1.predict(x_test)

# Calculate the mean absolute error
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Absolute Error: {mse}")

print(mse/np.mean(y_test))
print(np.mean(y_test))
# Out:
# Mean Absolute Error: 2.6898173864028544e-09
# 3.4612220947504e-06
# 0.0007771293816951166

# %%
fi = model_1.feature_importances_
#The impurity-based feature importances
print(fi)
big_df.head()
# Out:
# [0.69397417 0.25938019 0.01619574 0.03044989]
#              tp                 date   lat    lon  month  year        Cyclic
# 0  1.758273e-04  1950-01-01 00:00:00 -23.0  133.0      1  1950  8.660254e-01
# 1  1.707346e-03  1950-02-01 00:00:00 -23.0  133.0      2  1950  5.000000e-01
# 2  3.782110e-04  1950-03-01 00:00:00 -23.0  133.0      3  1950  6.123234e-17
# 3  9.355544e-07  1950-04-01 00:00:00 -23.0  133.0      4  1950 -5.000000e-01
# 4  8.622825e-04  1950-05-01 00:00:00 -23.0  133.0      5  1950 -8.660254e-01

# %%
df_cyclic = big_df

df_cyclic['Cyclic'] = df_cyclic['month'].apply(lambda x: np.cos(2*np.pi*x/12))

# %%
x_cols = ['Cyclic','year','lon','lat']
y_cols = ['tp']

X_data = big_df[x_cols]
Y_data = big_df[y_cols]


x_train, x_test, y_train, y_test = train_test_split(X_data,Y_data,test_size=0.2,random_state=0,shuffle = True)

# %%
model_2 = RandomForestRegressor(n_estimators=100,random_state=0)
model_2.fit(x_train,y_train)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# RandomForestRegressor(random_state=0)

# %%
f = model_2.feature_importances_
print(f)
#The impurity-based feature importances
# Out:
# [0.21857229 0.48387114 0.14662048 0.15093608]

# %%
y_pred = model_2.predict(x_test)

# Calculate the mean absolute error
mse = mean_squared_error(y_test, y_pred)

print(f"Mean Absolute Error: {mse}")

print(mse/np.mean(y_test))
print(np.mean(y_test))
# Out:
# Mean Absolute Error: 1.6425604905516207e-06
# 0.0021136255162155612
# 0.0007771293816951166
